# %%
from Plot_Data import stats, readinput, plotter

# %%
colors = ['mistyrose', 'palegreen', 'red', 'green']
plotter('ML311.txt', 'ML312.txt', colors[0], colors[1], colors[2], colors[3], '3Regular_Full.png')
plotter('ML321.txt', 'ML322.txt', colors[0], colors[1], colors[2], colors[3], '3Regular_R.png')
plotter('ML331.txt', 'ML332.txt', colors[0], colors[1], colors[2], colors[3], '3Restricted_Full.png')
plotter('ML341.txt', 'ML342.txt', colors[0], colors[1], colors[2], colors[3], '3Restricted_R.png')
plotter('ML351.txt', 'ML352.txt', colors[0], colors[1], colors[2], colors[3], '3Optimized.png')

# %%
colors = ['mistyrose', 'lightcyan', 'red', 'cyan']
plotter('ML211.txt', 'ML212.txt', colors[0], colors[1], colors[2], colors[3], '2Regular_Full.png')
plotter('ML221.txt', 'ML222.txt', colors[0], colors[1], colors[2], colors[3], '2Regular_R.png')
plotter('ML231.txt', 'ML232.txt', colors[0], colors[1], colors[2], colors[3], '2Restricted_Full.png')
plotter('ML241.txt', 'ML242.txt', colors[0], colors[1], colors[2], colors[3], '2Restricted_R.png')
plotter('ML251.txt', 'ML252.txt', colors[0], colors[1], colors[2], colors[3], '2Optimized.png')
