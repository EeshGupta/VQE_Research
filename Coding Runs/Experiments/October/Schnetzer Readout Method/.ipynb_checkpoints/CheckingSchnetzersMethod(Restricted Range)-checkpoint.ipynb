# %% [markdown]
# # Basic Libraries

# %%
# %matplotlib inline
# Importing standard Qiskit libraries and configuring account
from qiskit import QuantumCircuit, execute, Aer, IBMQ
from qiskit.compiler import transpile, assemble
from qiskit.tools.jupyter import *
from qiskit import *
from qiskit.visualization import *
# Loading your IBM Q account(s)
provider = IBMQ.load_account()

import math
import random

from qiskit.providers.aer.noise import NoiseModel
from qiskit.aqua import QuantumInstance
from qiskit.providers.aer.noise import thermal_relaxation_error, ReadoutError, depolarizing_error

# provider = IBMQ.get_provider(hub='ibm-q')
# machine = provider.get_backend('ibmq_valencia')
from qiskit.test.mock import FakeLondon
machine = FakeLondon()
machine_noise_model = NoiseModel.from_backend(machine)
simulator = Aer.get_backend('qasm_simulator')


basis_gates = machine_noise_model.basis_gates
# Out:
# C:\Users\Eesh Gupta\anacondaaa\lib\site-packages\qiskit\providers\ibmq\ibmqfactory.py:192: UserWarning: Timestamps in IBMQ backend properties, jobs, and job results are all now in local time instead of UTC.
#   warnings.warn('Timestamps in IBMQ backend properties, jobs, and job results '

# %% [markdown]
# # Important Functions

# %%
#Local Hamiltonian Function
from VQEHamiltonian_funcs import Hammifier

#Readout Mit Functions
from ReadoutMit import prepare_circuit, modify_counts, symmetry

# Expectation Value/Running Functions
from Result_ReadoutMit_funcs import binaryToDecimal, dictToList, sampleExpecVal, countToEig, expecValForSamples, addDicts, evaluator

# %% [markdown]
# # Restricted Range Info

# %%
'''------------Interatomic Distance = 0.74--------------
HF energy: -1.831863646477506
# of electrons: 2
# of spin orbitals: 4
Number of qubits are : 2
[ 0.00172129 -0.00182397 -0.11217598]
VQE Result: -1.1011690791894007 Exact Energy: -1.1372838344885012
All energies have been calculated'''
# Out:
# '------------Interatomic Distance = 0.74--------------\nHF energy: -1.831863646477506\n# of electrons: 2\n# of spin orbitals: 4\nNumber of qubits are : 2\n[ 0.00172129 -0.00182397 -0.11217598]\nVQE Result: -1.1011690791894007 Exact Energy: -1.1372838344885012\nAll energies have been calculated'

# %% [markdown]
# # Noise Model

# %%
'''

def generateDepolarizingError(machine, gate, qubits)

def generateRelaxationError(machine, gate, qubits, t1, t2, amp = 1, custom_t = False):
    """
    Return a relaxation error
    """

def generateNoiseModel(machine, coherent = True, incoherent = False, readout = False, custom_t = False, t1 = None, t2 = None, reverse = False):
    """
    Returns a realistic copy of london noise model with custom t1, t2 times
    """

'''

from NoiseModel import generateDepolarizingError, generateRelaxationError, generateNoiseModel

# %%
 noise_model = generateNoiseModel(machine, coherent = False, incoherent = False, readout= True)
# Out:
# Original: 0.01 0.050000000000000044
# Reverse: 0.01 0.050000000000000044
# Original: 0.02 0.07666666666666666
# Reverse: 0.02 0.07666666666666666
# Original: 0.14 0.18999999999999995
# Reverse: 0.14 0.18999999999999995
# Original: 0.0033333333333332993 0.03
# Reverse: 0.0033333333333332993 0.03
# Original: 0.006666666666666667 0.043333333333333335
# Reverse: 0.006666666666666667 0.043333333333333335

# %% [markdown]
# # Variational Form
# For Hydrogen

# %%
from qiskit.chemistry.components.variational_forms import UCCSD
from qiskit.chemistry.components.initial_states import HartreeFock

initial_state = HartreeFock(
4,
2,
'parity'
) 
var_form = UCCSD(
            num_orbitals=4,
            num_particles=2,
            initial_state=initial_state,
            qubit_mapping='parity'
        )

# %% [markdown]
# # Running Circuits for different Param

# %%
counter = 0

def EnergyFinder(param):
    '''
    Input: param (1D array) for which to compute energy on VQE circ of H2
    Output: energy
    '''
    
    Hamiltonian = """II\nIZ\nZI\nZZ\nXX"""
    Hamiltonian_weights = [-1.053, 0.395, -0.395, -0.011, 0.181]
    backend = simulator
    global noise_model
    samples = 8192
    
    
    
    circ = var_form.construct_circuit(param).decompose()
    circuits = Hammifier(circ, Hamiltonian)
    noisy_r = evaluator(circuits, samples, noise_model, Hamiltonian, Hamiltonian_weights, simulator, readout_mit = False)
    noisy_nr = evaluator(circuits, samples, noise_model, Hamiltonian, Hamiltonian_weights, simulator, readout_mit = True)
    ideal = evaluator(circuits, samples, None, Hamiltonian, Hamiltonian_weights, simulator, False)
    return noisy_r, noisy_nr, ideal

def main():
    '''
    Choose param and compute mean
    '''
    d = -math.pi
    u = math.pi
    
    energies = []
    diff_r = []
    diff_nr = []
    params = []
    
    for i in range(1000):
        print(i)
    
        p1 = random.uniform(0.001, 0.002)
        p2 = random.uniform(-0.002, -0.001)
        p3 = random.uniform(-0.2, -0.1)


        noisy_r,noisy_nr, ideal = EnergyFinder([p1,p2,p3])
        energies.append([[p1,p2,p3], ideal, noisy_r, noisy_nr])
        diff_r.append(noisy_r-ideal)
        diff_nr.append(noisy_nr-ideal)
        
        print('Noisy diff is ' + str(noisy_r-ideal))
        print('Mitigated diff is ' + str(noisy_nr-ideal))
        
    return energies, diff_r, diff_nr
energies, diff_r, diff_nr = main()
# Out:
# 0
# Noisy diff is 0.05620776367187519
# Mitigated diff is 0.054190185546874936
# 1
# Noisy diff is 0.06278442382812488
# Mitigated diff is 0.05360791015624988
# 2
# Noisy diff is 0.06060034179687501
# Mitigated diff is 0.05753295898437516
# 3
# Noisy diff is 0.05441601562499998
# Mitigated diff is 0.04962792968749996
# 4
# Noisy diff is 0.04970336914062523
# Mitigated diff is 0.043377441406249995
# 5
# Noisy diff is 0.05158178710937511
# Mitigated diff is 0.051735839843750187
# 6
# Noisy diff is 0.051024414062500245
# Mitigated diff is 0.05143041992187514
# 7
# Noisy diff is 0.053572753906249826
# Mitigated diff is 0.048147705078124936
# 8
# Noisy diff is 0.0583769531249998
# Mitigated diff is 0.056445068359374684
# 9
# Noisy diff is 0.05089916992187504
# Mitigated diff is 0.058087402343750094
# 10
# Noisy diff is 0.0542128906249999
# Mitigated diff is 0.057814941406249876
# 11
# Noisy diff is 0.04977075195312475
# Mitigated diff is 0.055421386718749854
# 12
# Noisy diff is 0.06705371093750001
# Mitigated diff is 0.06117675781249976
# 13
# Noisy diff is 0.06438452148437501
# Mitigated diff is 0.05528173828125005
# 14
# Noisy diff is 0.055220947265624876
# Mitigated diff is 0.058330810546874945
# 15
# Noisy diff is 0.05766723632812498
# Mitigated diff is 0.05643652343749994
# 16
# Noisy diff is 0.060541992187500115
# Mitigated diff is 0.05771972656250002
# 17
# Noisy diff is 0.05630834960937525
# Mitigated diff is 0.05362915039062521
# 18
# Noisy diff is 0.04746044921874981
# Mitigated diff is 0.0508395996093749
# 19
# Noisy diff is 0.0635322265624998
# Mitigated diff is 0.05834667968749985
# 20
# Noisy diff is 0.06465966796875011
# Mitigated diff is 0.06410839843749994
# 21
# Noisy diff is 0.07160083007812501
# Mitigated diff is 0.05826855468749992
# 22
# Noisy diff is 0.05898925781249997
# Mitigated diff is 0.05536474609374986
# 23
# Noisy diff is 0.05291723632812495
# Mitigated diff is 0.054330566406250114
# 24
# Noisy diff is 0.05746166992187507
# Mitigated diff is 0.05820727539062509
# 25
# Noisy diff is 0.05479980468749979
# Mitigated diff is 0.056707031249999984
# 26
# Noisy diff is 0.052071777343750014
# Mitigated diff is 0.0482314453124999
# 27
# Noisy diff is 0.06034008789062484
# Mitigated diff is 0.06798364257812484
# 28
# Noisy diff is 0.05425708007812502
# Mitigated diff is 0.054502441406249824
# 29
# Noisy diff is 0.06362011718749994
# Mitigated diff is 0.06096411132812496
# 30
# Noisy diff is 0.059654052734375185
# Mitigated diff is 0.06357836914062487
# 31
# Noisy diff is 0.06485375976562491
# Mitigated diff is 0.06661010742187501
# 32
# Noisy diff is 0.05021459960937458
# Mitigated diff is 0.051426269531249735
# 33
# Noisy diff is 0.059225830078124986
# Mitigated diff is 0.055438232421874956
# 34
# Noisy diff is 0.06551000976562493
# Mitigated diff is 0.058405273437499794
# 35
# Noisy diff is 0.06532373046874995
# Mitigated diff is 0.05420922851562482
# 36
# Noisy diff is 0.059215087890624796
# Mitigated diff is 0.05866113281249996
# 37
# Noisy diff is 0.06395825195312499
# Mitigated diff is 0.06709716796874998
# 38
# Noisy diff is 0.056611572265625076
# Mitigated diff is 0.05910278320312479
# 39
# Noisy diff is 0.06072656249999997
# Mitigated diff is 0.05629516601562479
# 40
# Noisy diff is 0.06159960937499975
# Mitigated diff is 0.05945581054687499
# 41
# Noisy diff is 0.061151611328124966
# Mitigated diff is 0.06186621093749989
# 42
# Noisy diff is 0.0471040039062498
# Mitigated diff is 0.050752441406249904
# 43
# Noisy diff is 0.05818847656249959
# Mitigated diff is 0.058959960937499556
# 44
# Noisy diff is 0.05771435546874981
# Mitigated diff is 0.0611103515625
# 45
# Noisy diff is 0.052868164062499945
# Mitigated diff is 0.049250244140624844
# 46
# Noisy diff is 0.0601650390624997
# Mitigated diff is 0.06371020507812486
# 47
# Noisy diff is 0.05939355468749996
# Mitigated diff is 0.068408447265625
# 48
# Noisy diff is 0.055707275390625144
# Mitigated diff is 0.06217187499999999
# 49
# Noisy diff is 0.06314794921875011
# Mitigated diff is 0.05560961914062501
# 50
# Noisy diff is 0.05974511718749986
# Mitigated diff is 0.05840039062499991
# 51
# Noisy diff is 0.06497802734375013
# Mitigated diff is 0.05558862304687495
# 52
# Noisy diff is 0.05592724609374988
# Mitigated diff is 0.04958325195312496
# 53
# Noisy diff is 0.049684082031249854
# Mitigated diff is 0.050911865234374964
# 54
# Noisy diff is 0.049314697265625096
# Mitigated diff is 0.04994213867187525
# 55
# Noisy diff is 0.05269384765624996
# Mitigated diff is 0.061836914062499915
# 56
# Noisy diff is 0.06105053710937458
# Mitigated diff is 0.06029785156249989
# 57
# Noisy diff is 0.061738525390625076
# Mitigated diff is 0.06286059570312497
# 58
# Noisy diff is 0.050070556640624986
# Mitigated diff is 0.051969970703125146
# 59
# Noisy diff is 0.050257568359375115
# Mitigated diff is 0.053070068359375
# 60
# Noisy diff is 0.06734155273437481
# Mitigated diff is 0.06233740234374996
# 61
# Noisy diff is 0.06407568359374971
# Mitigated diff is 0.061097167968749755
# 62
# Noisy diff is 0.056624511718749826
# Mitigated diff is 0.05516870117187489
# 63
# Noisy diff is 0.05870507812500003
# Mitigated diff is 0.05357446289062495
# 64
# Noisy diff is 0.05926708984374973
# Mitigated diff is 0.05478442382812476
# 65
# Noisy diff is 0.059721435546875146
# Mitigated diff is 0.05729223632812497
# 66
# Noisy diff is 0.05344140624999971
# Mitigated diff is 0.05140454101562497
# 67
# Noisy diff is 0.05994702148437492
# Mitigated diff is 0.05670874023437489
# 68
# Noisy diff is 0.05100024414062476
# Mitigated diff is 0.05755688476562493
# 69
# Noisy diff is 0.05576171874999991
# Mitigated diff is 0.06620092773437491
# 70
# Noisy diff is 0.05875927734374997
# Mitigated diff is 0.060165039062499925
# 71
# Noisy diff is 0.049904541015624915
# Mitigated diff is 0.05144628906250004
# 72
# Noisy diff is 0.0603327636718749
# Mitigated diff is 0.06000659179687484
# 73
# Noisy diff is 0.05868774414062483
# Mitigated diff is 0.055122314453124766
# 74
# Noisy diff is 0.04315893554687489
# Mitigated diff is 0.058293212890624835
# 75
# Noisy diff is 0.054411132812500096
# Mitigated diff is 0.057042236328124885
# 76
# Noisy diff is 0.05533178710937525
# Mitigated diff is 0.0559707031250003
# 77
# Noisy diff is 0.058808837890624854
# Mitigated diff is 0.05988574218749987
# 78
# Noisy diff is 0.05318749999999972
# Mitigated diff is 0.05383666992187508
# 79
# Noisy diff is 0.06008520507812509
# Mitigated diff is 0.04836425781250009
# 80
# Noisy diff is 0.06149536132812483
# Mitigated diff is 0.05944360351562472
# 81
# Noisy diff is 0.05618994140625033
# Mitigated diff is 0.06415039062500005
# 82
# Noisy diff is 0.0572331542968747
# Mitigated diff is 0.05602270507812479
# 83
# Noisy diff is 0.059802001953124795
# Mitigated diff is 0.04640942382812496
# 84
# Noisy diff is 0.061778076171874696
# Mitigated diff is 0.060633300781249844
# 85
# Noisy diff is 0.06058740234375004
# Mitigated diff is 0.05313745117187474
# 86
# Noisy diff is 0.059273681640624964
# Mitigated diff is 0.05983374023437493
# 87
# Noisy diff is 0.05599584960937487
# Mitigated diff is 0.06210229492187502
# 88
# Noisy diff is 0.058147705078124945
# Mitigated diff is 0.059896972656249936
# 89
# Noisy diff is 0.054461914062500005
# Mitigated diff is 0.06044726562499991
# 90
# Noisy diff is 0.061813232421874975
# Mitigated diff is 0.055025146484374954
# 91
# Noisy diff is 0.057551269531250115
# Mitigated diff is 0.055187255859374895
# 92
# Noisy diff is 0.066835693359375
# Mitigated diff is 0.06011254882812511
# 93
# Noisy diff is 0.050691406250000126
# Mitigated diff is 0.060161376953124845
# 94
# Noisy diff is 0.06336523437499997
# Mitigated diff is 0.06460961914062491
# 95
# Noisy diff is 0.04754638671875
# Mitigated diff is 0.04786230468749997
# 96
# Noisy diff is 0.05738354492187514
# Mitigated diff is 0.052881591796875016
# 97
# Noisy diff is 0.06621215820312498
# Mitigated diff is 0.0590805664062497
# 98
# Noisy diff is 0.06216357421874985
# Mitigated diff is 0.05854321289062492
# 99
# Noisy diff is 0.05765112304687481
# Mitigated diff is 0.058391601562499895
# 100
# Noisy diff is 0.05725122070312505
# Mitigated diff is 0.05582275390624991
# 101
# Noisy diff is 0.056711914062499647
# Mitigated diff is 0.05633154296874987
# 102
# Noisy diff is 0.060591552734374776
# Mitigated diff is 0.06272973632812495
# 103
# Noisy diff is 0.05491162109374992
# Mitigated diff is 0.05069580078124991
# 104
# Noisy diff is 0.05505078124999985
# Mitigated diff is 0.05627709960937466
# 105
# Noisy diff is 0.058307373046875055
# Mitigated diff is 0.06381835937500013
# 106
# Noisy diff is 0.0568205566406248
# Mitigated diff is 0.055883544921875083
# 107
# Noisy diff is 0.06416040039062487
# Mitigated diff is 0.061301269531250036
# 108
# Noisy diff is 0.05685400390625017
# Mitigated diff is 0.06107885742187502
# 109
# Noisy diff is 0.038566406250000185
# Mitigated diff is 0.04869213867187505
# 110
# Noisy diff is 0.05768774414062472
# Mitigated diff is 0.059795654296874945
# 111
# Noisy diff is 0.052325683593750005
# Mitigated diff is 0.054153564453125025
# 112
# Noisy diff is 0.04819384765624979
# Mitigated diff is 0.05057812499999992
# 113
# Noisy diff is 0.054831298828124764
# Mitigated diff is 0.0586816406249997
# 114
# Noisy diff is 0.058676513671874986
# Mitigated diff is 0.06266235351562521
# 115
# Noisy diff is 0.05521606445312477
# Mitigated diff is 0.05023413085937478
# 116
# Noisy diff is 0.06185278320312504
# Mitigated diff is 0.05686059570312496
# 117
# Noisy diff is 0.053902832031250014
# Mitigated diff is 0.06186669921874999
# 118
# Noisy diff is 0.05726831054687498
# Mitigated diff is 0.05715014648437511
# 119
# Noisy diff is 0.05750244140625016
# Mitigated diff is 0.0538630371093749
# 120
# Noisy diff is 0.058615478515624986
# Mitigated diff is 0.05849902343750002
# 121
# Noisy diff is 0.0672319335937499
# Mitigated diff is 0.06481811523437497
# 122
# Noisy diff is 0.054723388671874984
# Mitigated diff is 0.05714843749999998
# 123
# Noisy diff is 0.06092675781249968
# Mitigated diff is 0.05169995117187476
# 124
# Noisy diff is 0.06650073242187493
# Mitigated diff is 0.06513354492187506
# 125
# Noisy diff is 0.05312719726562509
# Mitigated diff is 0.05698559570312489
# 126
# Noisy diff is 0.06343579101562491
# Mitigated diff is 0.04838281249999987
# 127
# Noisy diff is 0.060314208984374895
# Mitigated diff is 0.05833837890624993
# 128
# Noisy diff is 0.05848339843749972
# Mitigated diff is 0.057238525390624906
# 129
# Noisy diff is 0.06208959960937488
# Mitigated diff is 0.05887573242187494
# 130
# Noisy diff is 0.060426513671874904
# Mitigated diff is 0.0626215820312499
# 131
# Noisy diff is 0.062389404296874895
# Mitigated diff is 0.06234277343749994
# 132
# Noisy diff is 0.057477539062500194
# Mitigated diff is 0.04992431640625017
# 133
# Noisy diff is 0.06140893554687499
# Mitigated diff is 0.05342333984375003
# 134
# Noisy diff is 0.0570837402343749
# Mitigated diff is 0.06118383789062509
# 135
# Noisy diff is 0.05241870117187508
# Mitigated diff is 0.05314477539062512
# 136
# Noisy diff is 0.05243164062500005
# Mitigated diff is 0.06490307617187474
# 137
# Noisy diff is 0.06368041992187501
# Mitigated diff is 0.06534765624999994
# 138
# Noisy diff is 0.06791162109375004
# Mitigated diff is 0.05867138671875005
# 139
# Noisy diff is 0.05436938476562503
# Mitigated diff is 0.05854638671875012
# 140
# Noisy diff is 0.05666113281249974
# Mitigated diff is 0.062019775390624865
# 141
# Noisy diff is 0.05878979492187475
# Mitigated diff is 0.05652075195312478
# 142
# Noisy diff is 0.06045996093750006
# Mitigated diff is 0.06199511718749995
# 143
# Noisy diff is 0.05658300781249981
# Mitigated diff is 0.04555151367187471
# 144
# Noisy diff is 0.066023681640625
# Mitigated diff is 0.06266528320312492
# 145
# Noisy diff is 0.055458496093749865
# Mitigated diff is 0.051070556640624654
# 146
# Noisy diff is 0.058608886718749975
# Mitigated diff is 0.053719482421874964
# 147
# Noisy diff is 0.055272949218750034
# Mitigated diff is 0.06226586914062504
# 148
# Noisy diff is 0.053262207031250286
# Mitigated diff is 0.05275341796874988
# 149
# Noisy diff is 0.06312988281249998
# Mitigated diff is 0.059449218749999755
# 150
# Noisy diff is 0.0561655273437498
# Mitigated diff is 0.06520214843749983
# 151
# Noisy diff is 0.06262475585937488
# Mitigated diff is 0.06347680664062505
# 152
# Noisy diff is 0.06050244140625005
# Mitigated diff is 0.06577319335937482
# 153
# Noisy diff is 0.06399584960937488
# Mitigated diff is 0.05738549804687487
# 154
# Noisy diff is 0.05071191406249964
# Mitigated diff is 0.0550815429687499
# 155
# Noisy diff is 0.05976611328124992
# Mitigated diff is 0.06392407226562491
# 156
# Noisy diff is 0.06042187499999985
# Mitigated diff is 0.06338183593750002
# 157
# Noisy diff is 0.05746118164062497
# Mitigated diff is 0.06563598632812506
# 158
# Noisy diff is 0.05797241210937498
# Mitigated diff is 0.06607446289062491
# 159
# Noisy diff is 0.0618437500000002
# Mitigated diff is 0.059552490234375144
# 160
# Noisy diff is 0.05912915039062483
# Mitigated diff is 0.060134765624999975
# 161
# Noisy diff is 0.06263818359375017
# Mitigated diff is 0.06040478515624992
# 162
# Noisy diff is 0.062081787109375064
# Mitigated diff is 0.066150146484375
# 163
# Noisy diff is 0.06094775390624996
# Mitigated diff is 0.06749365234374993
# 164
# Noisy diff is 0.059042724609374986
# Mitigated diff is 0.05552197265625014
# 165
# Noisy diff is 0.060915039062499954
# Mitigated diff is 0.06130859374999997
# 166
# Noisy diff is 0.0531337890625001
# Mitigated diff is 0.05957348632812476
# 167
# Noisy diff is 0.057869628906249915
# Mitigated diff is 0.06839355468749986
# 168
# Noisy diff is 0.05917675781249998
# Mitigated diff is 0.05244042968750029
# 169
# Noisy diff is 0.05940429687499993
# Mitigated diff is 0.06261450195312479
# 170
# Noisy diff is 0.05759497070312514
# Mitigated diff is 0.056513427734375066
# 171
# Noisy diff is 0.06167944335937481
# Mitigated diff is 0.05061572265625003
# 172
# Noisy diff is 0.06410302734374973
# Mitigated diff is 0.06358789062500003
# 173
# Noisy diff is 0.06035766601562487
# Mitigated diff is 0.0457426757812498
# 174
# Noisy diff is 0.061135253906249964
# Mitigated diff is 0.06037939453124985
# 175
# Noisy diff is 0.058396484375000224
# Mitigated diff is 0.059023437500000275
# 176
# Noisy diff is 0.05328613281249983
# Mitigated diff is 0.057279296874999996
# 177
# Noisy diff is 0.06526635742187481
# Mitigated diff is 0.06818505859374979
# 178
# Noisy diff is 0.06209741210937514
# Mitigated diff is 0.06785498046874983
# 179
# Noisy diff is 0.05615698242187506
# Mitigated diff is 0.06711254882812501
# 180
# Noisy diff is 0.05141479492187484
# Mitigated diff is 0.053261718749999964
# 181
# Noisy diff is 0.058361572265624995
# Mitigated diff is 0.05625610351562482
# 182
# Noisy diff is 0.05832934570312509
# Mitigated diff is 0.05658569335937491
# 183
# Noisy diff is 0.061690917968749925
# Mitigated diff is 0.06431103515624992
# 184
# Noisy diff is 0.04582031249999985
# Mitigated diff is 0.05567553710937512
# 185
# Noisy diff is 0.0528232421874999
# Mitigated diff is 0.06513671874999993
# 186
# Noisy diff is 0.05326220703124984
# Mitigated diff is 0.05608129882812474
# 187
# Noisy diff is 0.05813085937500029
# Mitigated diff is 0.06251660156250027
# 188
# Noisy diff is 0.060945556640624954
# Mitigated diff is 0.05954638671875001
# 189
# Noisy diff is 0.05281616210937501
# Mitigated diff is 0.04987280273437489
# 190
# Noisy diff is 0.06000976562499982
# Mitigated diff is 0.05763085937500012
# 191
# Noisy diff is 0.06018359374999993
# Mitigated diff is 0.062141601562499815
# 192
# Noisy diff is 0.05145825195312481
# Mitigated diff is 0.055458496093749865
# 193
# Noisy diff is 0.05955419921875005
# Mitigated diff is 0.04993969726562497
# 194
# Noisy diff is 0.061017089843750094
# Mitigated diff is 0.06303588867187515
# 195
# Noisy diff is 0.05333154296874998
# Mitigated diff is 0.05029907226562513
# 196
# Noisy diff is 0.05821484375000008
# Mitigated diff is 0.05551049804687502
# 197
# Noisy diff is 0.0515595703124998
# Mitigated diff is 0.06177124023437486
# 198
# Noisy diff is 0.05908789062499986
# Mitigated diff is 0.05523339843749975
# 199
# Noisy diff is 0.05132373046874994
# Mitigated diff is 0.05776562500000004
# 200
# Noisy diff is 0.05436083984374984
# Mitigated diff is 0.04600927734374993
# 201
# Noisy diff is 0.05538574218750014
# Mitigated diff is 0.055187988281250044
# 202
# Noisy diff is 0.05055786132812479
# Mitigated diff is 0.0489323730468747
# 203
# Noisy diff is 0.05635961914062482
# Mitigated diff is 0.053027099609374906
# 204
# Noisy diff is 0.05168554687499971
# Mitigated diff is 0.053382080078124616
# 205
# Noisy diff is 0.0600205078124999
# Mitigated diff is 0.059989013671874925
# 206
# Noisy diff is 0.062410156249999904
# Mitigated diff is 0.058897216796875096
# 207
# Noisy diff is 0.05093457031249993
# Mitigated diff is 0.0491943359375
# 208
# Noisy diff is 0.052539062499999734
# Mitigated diff is 0.052470947265624845
# 209
# Noisy diff is 0.06253662109374991
# Mitigated diff is 0.06218750000000006
# 210
# Noisy diff is 0.05540063476562462
# Mitigated diff is 0.05546752929687471
# 211
# Noisy diff is 0.04603881835937518
# Mitigated diff is 0.051025390625
# 212
# Noisy diff is 0.06259619140625006
# Mitigated diff is 0.05426660156249996
# 213
# Noisy diff is 0.060386474609375185
# Mitigated diff is 0.06150927734375
# 214
# Noisy diff is 0.056405029296875187
# Mitigated diff is 0.05675292968750001
# 215
# Noisy diff is 0.05699145507812475
# Mitigated diff is 0.05745068359374983
# 216
# Noisy diff is 0.05033911132812485
# Mitigated diff is 0.05931884765624984
# 217
# Noisy diff is 0.06932641601562484
# Mitigated diff is 0.0560292968749998
# 218
# Noisy diff is 0.055239501953125325
# Mitigated diff is 0.054109619140625176
# 219
# Noisy diff is 0.06573583984374998
# Mitigated diff is 0.05916674804687516
# 220
# Noisy diff is 0.048711181640624934
# Mitigated diff is 0.053806396484374686
# 221
# Noisy diff is 0.058798828125000036
# Mitigated diff is 0.06028320312500002
# 222
# Noisy diff is 0.05402099609375033
# Mitigated diff is 0.05586914062500026
# 223
# Noisy diff is 0.05628491210937492
# Mitigated diff is 0.0609909667968751
# 224
# Noisy diff is 0.05106835937499987
# Mitigated diff is 0.05462744140624998
# 225
# Noisy diff is 0.05746191406250034
# Mitigated diff is 0.060413574218750155
# 226
# Noisy diff is 0.053434082031249996
# Mitigated diff is 0.05164916992187507
# 227
# Noisy diff is 0.048036621093749954
# Mitigated diff is 0.05326635742187502
# 228
# Noisy diff is 0.07048901367187499
# Mitigated diff is 0.06275317382812484
# 229
# Noisy diff is 0.052637695312499844
# Mitigated diff is 0.06113012695312492
# 230
# Noisy diff is 0.04602807617187499
# Mitigated diff is 0.04952050781250006
# 231
# Noisy diff is 0.06283666992187498
# Mitigated diff is 0.06874218750000005
# 232
# Noisy diff is 0.05815698242187484
# Mitigated diff is 0.05960449218749986
# 233
# Noisy diff is 0.057306640625000016
# Mitigated diff is 0.06026220703125018
# 234
# Noisy diff is 0.05669995117187532
# Mitigated diff is 0.060861328125000114
# 235
# Noisy diff is 0.05233593749999965
# Mitigated diff is 0.05572167968749975
# 236
# Noisy diff is 0.06171728515624997
# Mitigated diff is 0.06072534179687494
# 237
# Noisy diff is 0.060063476562499885
# Mitigated diff is 0.06115771484374988
# 238
# Noisy diff is 0.07034814453125016
# Mitigated diff is 0.06634204101562502
# 239
# Noisy diff is 0.062164306640625
# Mitigated diff is 0.06757373046874982
# 240
# Noisy diff is 0.05399487304687489
# Mitigated diff is 0.04946972656249993
# 241
# Noisy diff is 0.05640380859374994
# Mitigated diff is 0.053061523437499813
# 242
# Noisy diff is 0.058001220703124856
# Mitigated diff is 0.057188476562499924
# 243
# Noisy diff is 0.05873901367187506
# Mitigated diff is 0.05762011718750015
# 244
# Noisy diff is 0.062179199218749925
# Mitigated diff is 0.058188476562500036
# 245
# Noisy diff is 0.06019677734374995
# Mitigated diff is 0.06821313476562496
# 246
# Noisy diff is 0.06246826171874997
# Mitigated diff is 0.059362060546874984
# 247
# Noisy diff is 0.06334619140624986
# Mitigated diff is 0.05122045898437477
# 248
# Noisy diff is 0.05613842773437505
# Mitigated diff is 0.0522314453124999
# 249
# Noisy diff is 0.053593749999999885
# Mitigated diff is 0.05521728515625002
# 250
# Noisy diff is 0.05844482421875008
# Mitigated diff is 0.058096679687499986
# 251
# Noisy diff is 0.05651831054687517
# Mitigated diff is 0.051698242187500076
# 252
# Noisy diff is 0.059051513671875
# Mitigated diff is 0.061131835937499934
# 253
# Noisy diff is 0.05672583007812482
# Mitigated diff is 0.053331787109374806
# 254
# Noisy diff is 0.06460717773437508
# Mitigated diff is 0.059111083984374924
# 255
# Noisy diff is 0.0559086914062501
# Mitigated diff is 0.05210009765625023
# 256
# Noisy diff is 0.06741381835937488
# Mitigated diff is 0.06936694335937488
# 257
# Noisy diff is 0.07492797851562483
# Mitigated diff is 0.06630126953124993
# 258
# Noisy diff is 0.04308422851562499
# Mitigated diff is 0.05705712890625003
# 259
# Noisy diff is 0.04862670898437482
# Mitigated diff is 0.05346289062499987
# 260
# Noisy diff is 0.06025878906249993
# Mitigated diff is 0.05814672851562497
# 261
# Noisy diff is 0.051461425781250014
# Mitigated diff is 0.04955297851562501
# 262
# Noisy diff is 0.05923828125000008
# Mitigated diff is 0.06106250000000024
# 263
# Noisy diff is 0.06393115234375024
# Mitigated diff is 0.05627050781250009
# 264
# Noisy diff is 0.05762963867187487
# Mitigated diff is 0.060063476562499885
# 265
# Noisy diff is 0.06166992187499987
# Mitigated diff is 0.06754150390624991
# 266
# Noisy diff is 0.052409912109374845
# Mitigated diff is 0.05609204101562493
# 267
# Noisy diff is 0.06077783203124976
# Mitigated diff is 0.055420898437499755
# 268
# Noisy diff is 0.05661645507812496
# Mitigated diff is 0.06298364257812494
# 269
# Noisy diff is 0.04983129882812509
# Mitigated diff is 0.0566086425781247
# 270
# Noisy diff is 0.0569138183593747
# Mitigated diff is 0.05282812499999978
# 271
# Noisy diff is 0.05837207031249969
# Mitigated diff is 0.05617626953124999
# 272
# Noisy diff is 0.05276196289062507
# Mitigated diff is 0.0629284667968748
# 273
# Noisy diff is 0.05318579101562482
# Mitigated diff is 0.05101416015624993
# 274
# Noisy diff is 0.056478759765624886
# Mitigated diff is 0.059693847656250076
# 275
# Noisy diff is 0.0711333007812498
# Mitigated diff is 0.057978271484374844
# 276
# Noisy diff is 0.05558081054687536
# Mitigated diff is 0.05524169921875011
# 277
# Noisy diff is 0.05732641601562505
# Mitigated diff is 0.06344335937500012
# 278
# Noisy diff is 0.05062915039062488
# Mitigated diff is 0.055513671875000004
# 279
# Noisy diff is 0.05844042968749985
# Mitigated diff is 0.05887109374999988
# 280
# Noisy diff is 0.06514819335937516
# Mitigated diff is 0.06702319335937501
# 281
# Noisy diff is 0.058913574218749876
# Mitigated diff is 0.05527978515624987
# 282
# Noisy diff is 0.05428027343750008
# Mitigated diff is 0.05979785156250017
# 283
# Noisy diff is 0.05897875976562483
# Mitigated diff is 0.05942773437499982
# 284
# Noisy diff is 0.06345361328124977
# Mitigated diff is 0.06525146484374988
# 285
# Noisy diff is 0.05428344726562506
# Mitigated diff is 0.0582585449218751
# 286
# Noisy diff is 0.06772192382812481
# Mitigated diff is 0.05527221679687466
# 287
# Noisy diff is 0.06024926757812521
# Mitigated diff is 0.06068994140625006
# 288
# Noisy diff is 0.06097656249999983
# Mitigated diff is 0.05870214843749988
# 289
# Noisy diff is 0.056028564453124874
# Mitigated diff is 0.058910888671874995
# 290
# Noisy diff is 0.0712634277343751
# Mitigated diff is 0.06844384765624989
# 291
# Noisy diff is 0.05937963867187479
# Mitigated diff is 0.053718261718749716
# 292
# Noisy diff is 0.04993359375000006
# Mitigated diff is 0.04955322265625006
# 293
# Noisy diff is 0.050436523437499936
# Mitigated diff is 0.059182128906249964
# 294
# Noisy diff is 0.05285864257812478
# Mitigated diff is 0.057100341796874954
# 295
# Noisy diff is 0.0575393066406249
# Mitigated diff is 0.05762402343750006
# 296
# Noisy diff is 0.060043212890624975
# Mitigated diff is 0.06093579101562496
# 297
# Noisy diff is 0.0631108398437501
# Mitigated diff is 0.05603002929687495
# 298
# Noisy diff is 0.04442358398437496
# Mitigated diff is 0.06017114257812506
# 299
# Noisy diff is 0.06416723632812493
# Mitigated diff is 0.06580566406249977
# 300
# Noisy diff is 0.06306713867187508
# Mitigated diff is 0.06322900390625019
# 301
# Noisy diff is 0.06212963867187504
# Mitigated diff is 0.06187109375000022
# 302
# Noisy diff is 0.05388916015624989
# Mitigated diff is 0.05968603515624982
# 303
# Noisy diff is 0.05611718749999994
# Mitigated diff is 0.04982836914062494
# 304
# Noisy diff is 0.057865722656249785
# Mitigated diff is 0.05394067382812484
# 305
# Noisy diff is 0.05693749999999986
# Mitigated diff is 0.06049243164062501
# 306
# Noisy diff is 0.054459472656250174
# Mitigated diff is 0.05390405273437526
# 307
# Noisy diff is 0.06098681640624992
# Mitigated diff is 0.0676755371093749
# 308
# Noisy diff is 0.053129638671874924
# Mitigated diff is 0.05997045898437503
# 309
# Noisy diff is 0.05891943359375018
# Mitigated diff is 0.05404321289062519
# 310
# Noisy diff is 0.05885839843749996
# Mitigated diff is 0.061077880859375044
# 311
# Noisy diff is 0.06745776367187495
# Mitigated diff is 0.064453125
# 312
# Noisy diff is 0.05133715820312479
# Mitigated diff is 0.05404321289062497
# 313
# Noisy diff is 0.06446923828125017
# Mitigated diff is 0.05463671875000031
# 314
# Noisy diff is 0.053302246093750005
# Mitigated diff is 0.0605
# 315
# Noisy diff is 0.056014404296874876
# Mitigated diff is 0.05207324218750009
# 316
# Noisy diff is 0.05013671874999992
# Mitigated diff is 0.04745849609374986
# 317
# Noisy diff is 0.0626062011718751
# Mitigated diff is 0.06366552734374986
# 318
# Noisy diff is 0.04779370117187498
# Mitigated diff is 0.05025610351562482
# 319
# Noisy diff is 0.0526865234374998
# Mitigated diff is 0.055098876953124876
# 320
# Noisy diff is 0.05933642578125009
# Mitigated diff is 0.05807055664062499
# 321
# Noisy diff is 0.06309155273437472
# Mitigated diff is 0.05895581054687482
# 322
# Noisy diff is 0.06319726562499994
# Mitigated diff is 0.061128173828125076
# 323
# Noisy diff is 0.054663818359374616
# Mitigated diff is 0.053698730468749734
# 324
# Noisy diff is 0.052100830078124716
# Mitigated diff is 0.055847900390624705
# 325
# Noisy diff is 0.05723388671875007
# Mitigated diff is 0.06452368164062516
# 326
# Noisy diff is 0.05443188476562488
# Mitigated diff is 0.058255859374999996
# 327
# Noisy diff is 0.04562060546875024
# Mitigated diff is 0.06459179687499983
# 328
# Noisy diff is 0.05543334960937507
# Mitigated diff is 0.056804931640624945
# 329
# Noisy diff is 0.05830859374999986
# Mitigated diff is 0.050569824218750004
# 330
# Noisy diff is 0.0672106933593748
# Mitigated diff is 0.04685034179687486
# 331
# Noisy diff is 0.06394873046874983
# Mitigated diff is 0.06452246093749991
# 332
# Noisy diff is 0.059938232421874904
# Mitigated diff is 0.055848876953124904
# 333
# Noisy diff is 0.06280151367187492
# Mitigated diff is 0.05731079101562475
# 334
# Noisy diff is 0.054591552734375215
# Mitigated diff is 0.04875708007812518
# 335
# Noisy diff is 0.06363183593749999
# Mitigated diff is 0.06417944335937498
# 336
# Noisy diff is 0.05744409179687482
# Mitigated diff is 0.06285034179687488
# 337
# Noisy diff is 0.056715576171874726
# Mitigated diff is 0.0587416992187495
# 338
# Noisy diff is 0.0638444824218749
# Mitigated diff is 0.05848999023437518
# 339
# Noisy diff is 0.06381469726562461
# Mitigated diff is 0.06946874999999975
# 340
# Noisy diff is 0.06313940429687492
# Mitigated diff is 0.06539526367187487
# 341
# Noisy diff is 0.053428222656250135
# Mitigated diff is 0.0607915039062501
# 342
# Noisy diff is 0.0568383789062501
# Mitigated diff is 0.0583359375000001
# 343
# Noisy diff is 0.0636296386718751
# Mitigated diff is 0.06368701171875002
# 344
# Noisy diff is 0.051373046874999995
# Mitigated diff is 0.04973974609374987
# 345
# Noisy diff is 0.05470776367187513
# Mitigated diff is 0.05777465820312511
# 346
# Noisy diff is 0.06290307617187474
# Mitigated diff is 0.06366918945312472
# 347
# Noisy diff is 0.06265161132812502
# Mitigated diff is 0.05982836914062517
# 348
# Noisy diff is 0.04784667968749989
# Mitigated diff is 0.053404296875000146
# 349
# Noisy diff is 0.06670800781249997
# Mitigated diff is 0.06125927734374992
# 350
# Noisy diff is 0.05673095703124997
# Mitigated diff is 0.05620312499999991
# 351
# Noisy diff is 0.062301025390624876
# Mitigated diff is 0.06302343749999983
# 352
# Noisy diff is 0.06039404296874995
# Mitigated diff is 0.06499316406249989
# 353
# Noisy diff is 0.05493774414062491
# Mitigated diff is 0.039826660156249805
# 354
# Noisy diff is 0.062457031249999906
# Mitigated diff is 0.06034423828125002
# 355
# Noisy diff is 0.06295385742187509
# Mitigated diff is 0.06557812500000004
# 356
# Noisy diff is 0.0557246093749999
# Mitigated diff is 0.055472412109374813
# 357
# Noisy diff is 0.06249023437500001
# Mitigated diff is 0.051555419921874845
# 358
# Noisy diff is 0.05784033203124994
# Mitigated diff is 0.055757568359375176
# 359
# Noisy diff is 0.061868164062500064
# Mitigated diff is 0.06548730468749975
# 360
# Noisy diff is 0.05803759765624994
# Mitigated diff is 0.05852832031249977
# 361
# Noisy diff is 0.062468261718750195
# Mitigated diff is 0.05890209960937498
# 362
# Noisy diff is 0.05977758789062504
# Mitigated diff is 0.060929443359375224
# 363
# Noisy diff is 0.06207885742187513
# Mitigated diff is 0.06482275390625003
# 364
# Noisy diff is 0.05401220703124965
# Mitigated diff is 0.056929199218749726
# 365
# Noisy diff is 0.06396874999999991
# Mitigated diff is 0.05501293945312491
# 366
# Noisy diff is 0.044638427734374986
# Mitigated diff is 0.050924560546874886
# 367
# Noisy diff is 0.0594335937499999
# Mitigated diff is 0.06467236328125003
# 368
# Noisy diff is 0.05726489257812517
# Mitigated diff is 0.054401367187500105
# 369
# Noisy diff is 0.062081298828124964
# Mitigated diff is 0.05121264648437518
# 370
# Noisy diff is 0.05954638671874979
# Mitigated diff is 0.06099682617187474
# 371
# Noisy diff is 0.06487402343750004
# Mitigated diff is 0.062183349609375105
# 372
# Noisy diff is 0.06026245117187501
# Mitigated diff is 0.06644335937500001
# 373
# Noisy diff is 0.06232714843749987
# Mitigated diff is 0.06093652343749989
# 374
# Noisy diff is 0.053200683593749964
# Mitigated diff is 0.061086914062499886
# 375
# Noisy diff is 0.05515234374999989
# Mitigated diff is 0.05057397460937496
# 376
# Noisy diff is 0.06549096679687505
# Mitigated diff is 0.06675634765624983
# 377
# Noisy diff is 0.04859008789062513
# Mitigated diff is 0.05660668945312497
# 378
# Noisy diff is 0.06072680664062502
# Mitigated diff is 0.05686401367187499
# 379
# Noisy diff is 0.060759033203124924
# Mitigated diff is 0.05174438476562515
# 380
# Noisy diff is 0.06506347656249978
# Mitigated diff is 0.060103027343749726
# 381
# Noisy diff is 0.056455322265624774
# Mitigated diff is 0.054743164062499794
# 382
# Noisy diff is 0.057937744140625025
# Mitigated diff is 0.05804345703125002
# 383
# Noisy diff is 0.05956738281249985
# Mitigated diff is 0.05494848632812488
# 384
# Noisy diff is 0.06946166992187486
# Mitigated diff is 0.0646003417968748
# 385
# Noisy diff is 0.05364721679687512
# Mitigated diff is 0.05127612304687479
# 386
# Noisy diff is 0.05439477539062487
# Mitigated diff is 0.055895996093749956
# 387
# Noisy diff is 0.05503955078124978
# Mitigated diff is 0.052837890624999884
# 388
# Noisy diff is 0.05358178710937511
# Mitigated diff is 0.05673632812500018
# 389
# Noisy diff is 0.053926025390624854
# Mitigated diff is 0.05640600585937472
# 390
# Noisy diff is 0.05681689453124994
# Mitigated diff is 0.052020751953125055
# 391
# Noisy diff is 0.058581787109375005
# Mitigated diff is 0.06136010742187503
# 392
# Noisy diff is 0.0507033691406249
# Mitigated diff is 0.05393115234375001
# 393
# Noisy diff is 0.05395019531249989
# Mitigated diff is 0.0638410644531251
# 394
# Noisy diff is 0.056846191406250135
# Mitigated diff is 0.061776123046874964
# 395
# Noisy diff is 0.05069262695312515
# Mitigated diff is 0.053170654296875064
# 396
# Noisy diff is 0.05808520507812487
# Mitigated diff is 0.06010839843749993
# 397
# Noisy diff is 0.057289794921874915
# Mitigated diff is 0.05562622070312484
# 398
# Noisy diff is 0.061016113281249895
# Mitigated diff is 0.05988696289062512
# 399
# Noisy diff is 0.06188720703124995
# Mitigated diff is 0.05970288085937492
# 400
# Noisy diff is 0.05573144531249996
# Mitigated diff is 0.05843115234374996
# 401
# Noisy diff is 0.061155029296874996
# Mitigated diff is 0.06036987304687491
# 402
# Noisy diff is 0.05957104492187493
# Mitigated diff is 0.06513818359375012
# 403
# Noisy diff is 0.052804199218750014
# Mitigated diff is 0.06140966796875014
# 404
# Noisy diff is 0.05707202148437496
# Mitigated diff is 0.05827465820312483
# 405
# Noisy diff is 0.05569970703124971
# Mitigated diff is 0.05911840820312486
# 406
# Noisy diff is 0.05286743164062502
# Mitigated diff is 0.052521240234374655
# 407
# Noisy diff is 0.05708569335937508
# Mitigated diff is 0.05757714843750006
# 408
# Noisy diff is 0.05430419921875007
# Mitigated diff is 0.05647656249999988
# 409
# Noisy diff is 0.05759912109374987
# Mitigated diff is 0.05727734375000004
# 410
# Noisy diff is 0.05713354492187506
# Mitigated diff is 0.058334960937500124
# 411
# Noisy diff is 0.05209057617187485
# Mitigated diff is 0.051182373046874785
# 412
# Noisy diff is 0.06047192382812483
# Mitigated diff is 0.05614746093749989
# 413
# Noisy diff is 0.062345947265625146
# Mitigated diff is 0.06051196289062499
# 414
# Noisy diff is 0.05734790039062476
# Mitigated diff is 0.0571752929687499
# 415
# Noisy diff is 0.05309375000000016
# Mitigated diff is 0.0567468261718751
# 416
# Noisy diff is 0.05530200195312518
# Mitigated diff is 0.05718310546875016
# 417
# Noisy diff is 0.06340747070312491
# Mitigated diff is 0.0673234863281249
# 418
# Noisy diff is 0.05293017578124992
# Mitigated diff is 0.05158422851562516
# 419
# Noisy diff is 0.059619873046875105
# Mitigated diff is 0.06533520507812485
# 420
# Noisy diff is 0.059310546874999925
# Mitigated diff is 0.05904663085937489
# 421
# Noisy diff is 0.05365869140624957
# Mitigated diff is 0.05986108398437473
# 422
# Noisy diff is 0.05667553710937501
# Mitigated diff is 0.05048315429687511
# 423
# Noisy diff is 0.05696582031249975
# Mitigated diff is 0.047740478515624796
# 424
# Noisy diff is 0.05632202148437515
# Mitigated diff is 0.06366430664062506
# 425
# Noisy diff is 0.06549047851562517
# Mitigated diff is 0.06432421875000016
# 426
# Noisy diff is 0.04970336914062501
# Mitigated diff is 0.05040136718750032
# 427
# Noisy diff is 0.053484863281249906
# Mitigated diff is 0.05225830078124982
# 428
# Noisy diff is 0.049731933593750055
# Mitigated diff is 0.052275146484374924
# 429
# Noisy diff is 0.05562988281250014
# Mitigated diff is 0.059541748046875176
# 430
# Noisy diff is 0.06245214843750002
# Mitigated diff is 0.055734375000000114
# 431
# Noisy diff is 0.059415771484375046
# Mitigated diff is 0.05741601562499987
# 432
# Noisy diff is 0.06672412109374992
# Mitigated diff is 0.07049145507812504
# 433
# Noisy diff is 0.05877270507812504
# Mitigated diff is 0.06543432617187506
# 434
# Noisy diff is 0.05398950195312491
# Mitigated diff is 0.0674018554687501
# 435
# Noisy diff is 0.05056274414062489
# Mitigated diff is 0.057458984374999744
# 436
# Noisy diff is 0.05697045898437514
# Mitigated diff is 0.05564672851562502
# 437
# Noisy diff is 0.0561354980468749
# Mitigated diff is 0.06035668945312489
# 438
# Noisy diff is 0.055557617187500075
# Mitigated diff is 0.059168945312500165
# 439
# Noisy diff is 0.05926586914062493
# Mitigated diff is 0.053440673828124785
# 440
# Noisy diff is 0.05928320312500013
# Mitigated diff is 0.06695751953124995
# 441
# Noisy diff is 0.054312011718749886
# Mitigated diff is 0.0557277832031251
# 442
# Noisy diff is 0.04993847656249972
# Mitigated diff is 0.05180102539062492
# 443
# Noisy diff is 0.061087158203124936
# Mitigated diff is 0.05211352539062486
# 444
# Noisy diff is 0.045844726562499716
# Mitigated diff is 0.055055664062499954
# 445
# Noisy diff is 0.055197509765624986
# Mitigated diff is 0.05581982421874998
# 446
# Noisy diff is 0.04368432617187512
# Mitigated diff is 0.05187353515625015
# 447
# Noisy diff is 0.06528979492187514
# Mitigated diff is 0.05833666992187503
# 448
# Noisy diff is 0.05041918945312496
# Mitigated diff is 0.056563232421875
# 449
# Noisy diff is 0.060782470703124813
# Mitigated diff is 0.06465673828124996
# 450
# Noisy diff is 0.056615722656250034
# Mitigated diff is 0.048182861328125215
# 451
# Noisy diff is 0.06315893554687513
# Mitigated diff is 0.05793359375000007
# 452
# Noisy diff is 0.06050903320312484
# Mitigated diff is 0.05549316406249982
# 453
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-a822d5a7ef88> in <module>
#      51
#      52     return energies, diff_r, diff_nr
# ---> 53 energies, diff_r, diff_nr = main()
#
# <ipython-input-7-a822d5a7ef88> in main()
#      42
#      43
# ---> 44         noisy_r,noisy_nr, ideal = EnergyFinder([p1,p2,p3])
#      45         energies.append([[p1,p2,p3], ideal, noisy_r, noisy_nr])
#      46         diff_r.append(noisy_r-ideal)
#
# <ipython-input-7-a822d5a7ef88> in EnergyFinder(param)
#      19     noisy_r = evaluator(circuits, samples, noise_model, Hamiltonian, Hamiltonian_weights, simulator, readout_mit = False)
#      20     noisy_nr = evaluator(circuits, samples, noise_model, Hamiltonian, Hamiltonian_weights, simulator, readout_mit = True)
# ---> 21     ideal = evaluator(circuits, samples, None, Hamiltonian, Hamiltonian_weights, simulator, False)
#      22     return noisy_r, noisy_nr, ideal
#      23
#
# ~\Downloads\Schnetzer Readout Method\Result_ReadoutMit_funcs.py in evaluator(circuits, samples, noise_model, Hamiltonian, hammy_weights, simulator, readout_mit)
#     188
#     189     ##resizing now
# --> 190     for key in n_keys:
#     191         old_shots= n_counts[key]
#     192         n_counts[key] = int((old_shots/mod_shots)*shots)
#
# ~\Downloads\Schnetzer Readout Method\Result_ReadoutMit_funcs.py in expecValForSamples(counts_zsis, counts_xx, Hamiltonian, hammy_weights)
#     104         index1 = random.randrange(0, len(list_zsis))
#     105         index2 = random.randrange(0, len(list_xx))
# --> 106
#     107         exp_val= sampleExpecVal(list_zsis[index1], list_xx[index2], Hamiltonian, hammy_weights)
#     108         expec_vals.append(exp_val)
#
# ~\Downloads\Schnetzer Readout Method\Result_ReadoutMit_funcs.py in sampleExpecVal(samp_zsis, samp_xx, Hamiltonian, Hamiltonian_weights)
#      41         if (hammy!= 'XX'):
#      42             Hamiltonian_eig+= [countToEig(samp_zsis, hammy)]
# ---> 43         else:
#      44             Hamiltonian_eig+= [countToEig(samp_xx, hammy)]
#      45
#
# ~\Downloads\Schnetzer Readout Method\Result_ReadoutMit_funcs.py in countToEig(count, matrix)
#      83 #     print(second)
#      84
# ---> 85     #computing eigenvalue of kron(first, second)
#      86     v, w = np.linalg.eig(np.kron(first, second))
#      87     #convert count to dec
#
# <__array_function__ internals> in eig(*args, **kwargs)
#
# ~\anacondaaa\lib\site-packages\numpy\linalg\linalg.py in eig(a)
#    1299         _raise_linalgerror_eigenvalues_nonconvergence)
#    1300     signature = 'D->DD' if isComplexType(t) else 'd->DD'
# -> 1301     w, vt = _umath_linalg.eig(a, signature=signature, extobj=extobj)
#    1302
#    1303     if not isComplexType(t) and all(w.imag == 0.0):
#
# KeyboardInterrupt:

# %%
import numpy as np
import matplotlib.pyplot as plt

a = plt.figure()
plt.hist(diff_r, bins=100, color = "orangered", label = 'Noisy')
#plt.hist(diff_nr, bins=100, color = "lightcoral", label = 'Mitigated')
plt.title("Noisy - Ideal Energy ")
plt.xlabel("Energy Difference (Hartree)")
plt.ylabel("Frequency")
plt.legend()
plt.show()
a.savefig('SchnMethod_noisy_restricted.png', dpi = 1000)

# %%
a = plt.figure()
#plt.hist(diff_r, bins=100, color = "red", label = 'Noisy')
plt.hist(diff_nr, bins=100, color = "lightsalmon", label = 'Mitigated')
plt.title("Noisy - Ideal Energy (Schnetzer Method)")
plt.xlabel("Energy Difference (Hartree)")
plt.ylabel("Frequency")
plt.legend()
plt.show()
a.savefig('SchnMethod_Mitigated_Restricted.png', dpi = 1000)

# %%
energies

# %%
diff_r

# %%
diff_nr

# %% [markdown]
# # Without Readout
